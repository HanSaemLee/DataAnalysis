# %% [markdown]
# # Pandas 시각화 기능

# %%
# 항상 초기화
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='Malgun Gothic')

# %%
iris = sns.load_dataset("iris")
titanic = sns.load_dataset("titanic")
tipss = sns.load_dataset("tips")
flights = sns.load_dataset("flights")

# %% [markdown]
# ## Line Plot
# - Pandas의 시리즈나 데이터프레임은 plot이라는 시각화 메서드를 내장하고 있다

# %%
np.random.seed(2021)
df1 = pd.DataFrame(np.random.randn(100, 3),
                    index=pd.date_range('1/1/2021', periods=100),
                    columns=['A','B','C']).cumsum()
df1.tail()
# Out:
#                     A          B          C
# 2021-04-06  19.553541  11.530579  -8.757243
# 2021-04-07  20.909591  10.466816 -10.143565
# 2021-04-08  22.435144  11.674278  -7.474442
# 2021-04-09  22.546156  10.547727  -7.594791
# 2021-04-10  21.319639   9.825032  -8.213817

# %%
# Pandas의 plot()
df1.plot()
plt.title("Pandas의 Plot메소드 사용 예")
plt.xlabel("시간")
plt.ylabel("Data")
plt.show()

# %% [markdown]
# ## Bar Chart
# - plot메서드의 kind라는 인수를 바꾸면 여러가지 플롯을 그릴 수 있다

# %%
iris.sepal_length[:20].plot(kind='bar', rot=0)
plt.title("꽃받침의 길이 시각화")
plt.xlabel("Data")
plt.ylabel("꽃받침의 길이")
plt.show()

# %%
iris[:5].plot.bar(rot=0)
plt.title("Iris 데이터의 Bar Plot")
plt.xlabel("Data")
plt.ylabel("각 Feature의 값")
plt.ylim(0, 7)
plt.show()

# %%
iris.sepal_length[:20].sort_values()
# Out:
# 13    4.3
# 8     4.4
# 3     4.6
# 6     4.6
# 2     4.7
# 12    4.8
# 11    4.8
# 9     4.9
# 1     4.9
# 4     5.0
# 7     5.0
# 17    5.1
# 0     5.1
# 19    5.1
# 16    5.4
# 5     5.4
# 10    5.4
# 18    5.7
# 15    5.7
# 14    5.8
# Name: sepal_length, dtype: float64

# %%
iris.sepal_length[:20].sort_values().plot(kind='barh', rot=0,   # sort_values() 값을 기준으로 정렬
                            color=plt.get_cmap('RdBu')(np.linspace(0.8,0.2,20)))
plt.title("꽃받침의 길이 시각화")
plt.ylabel("Data")
plt.xlabel("꽃받침의 길이")
plt.show()

# %%
iris[:5].plot.bar(rot=0)
plt.ylim(0,7)
plt.show()

# %%
df2 = iris.groupby(iris.species).mean()
df2.columns.name = 'feature'
df2
# Out:
# feature     sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
df2.plot.bar(rot=0) # rot은 이름 각도
plt.title('각 종의 feature별 평균')
plt.ylim(0,10)   # y의 범위
plt.show()

# %%
df2.T.plot.bar(rot=0)
plt.title('각 feature의 종별 평균')
plt.show()

# %% [markdown]
# ## Pie Chart

# %%
df3 = titanic['class'].value_counts()
df3.plot.pie(autopct='%.2f%%')
plt.title('선실별 승객수 비율')
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Histogram

# %%
iris.plot.hist()
plt.title("각 Feature 값들의 빈도수 Histogram")
plt.xlabel("데이터 값")
plt.show()

# %% [markdown]
# ## Box Plot

# %%
iris.plot.box()
plt.title("각 Feature 값들의 빈도수에 대한 Box Plot")
plt.xlabel("Feature")
plt.ylabel("데이터 값")
plt.show()

# %%
iris.boxplot(by='species')
plt.tight_layout(pad=3, h_pad=1)
plt.title("각 Feature의 종 별 데이터에 대한 Box Plot")
plt.show()
